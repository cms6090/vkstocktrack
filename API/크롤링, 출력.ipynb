# %% [markdown]
# # 크롤링

# %%
# 라이브러리 불러오기
import yfinance as yf
import pandas as pd
import cloudscraper

# %%
def convert(value):  # 끝이 M, K일때 숫자로 변환
    if isinstance(value, str):  # 입력값이 문자열인 경우만 처리
        if "K" in value:
            return float(value.replace("K", "")) * 1000
        if "M" in value:
            return float(value.replace("M", "")) * 1000000
    return value

# %%
def update_data(ticker_name):
    if ticker_name == "^VNINDEX.VN":
        scraper = cloudscraper.create_scraper()
        html = scraper.get(
            "https://www.investing.com/indices/vn-historical-data"
        ).content
        dfs = pd.read_html(html)

        if len(dfs) > 0:
            df = dfs[0]
        else:
            print("데이터를 찾을 수 없습니다.")
            return None

        df = df.drop(columns=["Change %"])
        df = df.fillna(0)
        df = df.rename(columns={"Vol.": "Volume", "Price": "Close"})
        df["Volume"] = df["Volume"].apply(convert)
        df["Date"] = pd.to_datetime(df["Date"], format="%m/%d/%Y")
        df.set_index("Date", inplace=True)

        data = pd.read_csv(ticker_name + ".csv", index_col="Date")
        data.index = pd.to_datetime(data.index)
        data = data.fillna(0)
        merged_data = pd.concat([data, df])

        for col in ["Open", "High", "Close", "Low"]:
            merged_data[col] = pd.to_numeric(
                merged_data[col].astype(str).str.replace(",", ""), errors="coerce"
            )

        # Remove duplicates if any.
        merged_data = merged_data.loc[~merged_data.index.duplicated(keep="first")]

        # Sort the dataframe based on date.
        merged_data.sort_index(inplace=True)
        merged_data.index = merged_data.index.astype(str)
        merged_data = merged_data.fillna(0)
        # Save to csv.
        merged_data.to_csv(ticker_name + ".csv", index=True)

    else:
        data = yf.download(ticker_name)
        data = data.sort_values(by="Date", ascending=True)
        data = data.drop(columns=["Adj Close"])
        data.to_csv(ticker_name + ".csv", encoding="utf-8-sig")
        data.index = data.index.astype(str)

# %%
def output_data(ticker_name):
    data = pd.read_csv(ticker_name+'.csv')
    data = data.set_index('Date')
    if data['Open'].iloc[-1] == 0:
        data = data[:-1]
    return data

# %%
update_data("^KS11")
output_data('^KS11')
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close  Volume
# Date
# 1996-12-11   705.989990   709.479980   704.429993   704.679993   28000
# 1996-12-12   705.109985   706.010010   688.739990   689.380005   25900
# 1996-12-13   690.440002   695.719971   677.640015   689.070007   26500
# 1996-12-16   686.969971   686.969971   667.710022   673.919983   22800
# 1996-12-17   675.349976   680.090027   660.390015   663.349976   31600
# ...                 ...          ...          ...          ...     ...
# 2024-01-03  2643.540039  2643.719971  2607.310059  2607.310059  463100
# 2024-01-04  2592.439941  2602.639893  2580.090088  2587.020020  770200
# 2024-01-05  2586.889893  2592.290039  2572.600098  2578.080078  520500
# 2024-01-08  2584.229980  2591.679932  2566.340088  2567.820068  320100
# 2024-01-09  2598.310059  2599.370117  2556.000000  2561.239990  791214
#
# [6673 rows x 5 columns]

# %%
update_data("055550.KS")
output_data('055550.KS')
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                     Open          High           Low         Close     Volume
# Date
# 2000-01-04  18688.708984  20234.212891  18308.277344  19259.357422  197145699
# 2000-01-05  19021.585938  19592.234375  18070.507812  18664.931641  186396333
# 2000-01-06  18807.593750  19497.126953  16406.119141  17119.427734  184079807
# 2000-01-07  18546.046875  18878.923828  17618.744141  18070.507812  256406581
# 2000-01-10  18783.816406  19211.802734  18546.046875  18926.478516  988218404
# ...                  ...           ...           ...           ...        ...
# 2024-01-03  38800.000000  39200.000000  37900.000000  37900.000000     931521
# 2024-01-04  37950.000000  38000.000000  37050.000000  37300.000000     887191
# 2024-01-05  37100.000000  37300.000000  36650.000000  36850.000000     671689
# 2024-01-08  37100.000000  37350.000000  36750.000000  36950.000000     356649
# 2024-01-09  37450.000000  37500.000000  36800.000000  37250.000000     388703
#
# [6023 rows x 5 columns]

# %%
update_data("^VNINDEX.VN")
output_data('^VNINDEX.VN')
# Out:
#               Close     Open     High      Low    Volume
# Date
# 2000-07-31   101.55   101.55   101.55   101.55      10.0
# 2000-08-02   103.38   103.38   103.38   103.38       0.0
# 2000-08-04   105.20   105.20   105.20   105.20       0.0
# 2000-08-07   106.92   106.92   106.92   106.92      10.0
# 2000-08-09   108.64   108.64   108.64   108.64      20.0
# ...             ...      ...      ...      ...       ...
# 2024-01-03  1144.17  1131.72  1144.17  1128.32  719930.0
# 2024-01-04  1147.43  1145.49  1148.93  1144.32  248380.0
# 2024-01-05  1154.68  1150.72  1155.84  1149.08  803270.0
# 2024-01-08  1160.19  1154.68  1162.56  1154.68  905410.0
# 2024-01-09  1158.59  1160.19  1162.83  1155.46  870510.0
#
# [5668 rows x 5 columns]

# %%
update_data("VCB.VN")
output_data('VCB.VN')
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                     Open          High           Low         Close    Volume
# Date
# 2009-06-30  22898.183594  22898.183594  22898.183594  22898.183594    770543
# 2009-07-01  24043.093750  24043.093750  22707.365234  23089.001953  16372619
# 2009-07-02  22707.365234  22898.183594  21944.093750  22134.912109   3971498
# 2009-07-03  21562.457031  21753.275391  21371.638672  21371.638672   2357526
# 2009-07-06  21371.638672  22325.730469  21371.638672  22325.730469   4118416
# ...                  ...           ...           ...           ...       ...
# 2024-01-03  83500.000000  84500.000000  82800.000000  84500.000000   1521100
# 2024-01-04  84500.000000  86200.000000  84000.000000  85900.000000   2734900
# 2024-01-05  85900.000000  86200.000000  85700.000000  86200.000000   1328400
# 2024-01-08  86300.000000  86800.000000  86300.000000  86800.000000   1652800
# 2024-01-09  86800.000000  87900.000000  86800.000000  87800.000000   2074500
#
# [3623 rows x 5 columns]

# %% [markdown]
# ### 환율(USD_VND)

# %% [markdown]
# #usd_vnd1 = pd.read_csv('USD_VND Historical Data.csv')
# #usd_vnd2 = pd.read_csv('USD_VND Historical Data (1).csv')
# #usd_vnd = pd.concat([usd_vnd1,usd_vnd2])
# #usd_vnd['Date'] = pd.to_datetime(usd_vnd['Date'], format='%m/%d/%Y').dt.date
# #usd_vnd = usd_vnd.sort_values('Date')
# #usd_vnd = usd_vnd.set_index('Date')
# #usd_vnd.to_csv('usd_vnd.csv', index=True, encoding='utf-8-sig')
#
# get_data_investing_exchange('https://www.investing.com/currencies/usd-vnd-historical-data', 'usd_vnd')

# %% [markdown]
# ### 환율(USD_KRW)

# %% [markdown]
# #usd_krw1 = pd.read_csv('USD_KRW Historical Data.csv')
# #usd_krw2 = pd.read_csv('USD_KRW Historical Data (1).csv')
# #usd_krw = pd.concat([usd_krw1,usd_krw2])
# #usd_krw['Date'] = pd.to_datetime(usd_krw['Date'], format='%m/%d/%Y').dt.date
# #usd_krw = usd_krw.sort_values('Date')
# #usd_krw = usd_krw.set_index('Date')
# #usd_krw.to_csv('usd_krw.csv', index=True, encoding='utf-8-sig')
#
# get_data_investing_exchange('https://www.investing.com/currencies/usd-krw-historical-data', 'usd_krw')

# %% [markdown]
# ## 출력

# %%
def country_output(ticker_name):
    data = pd.read_csv(ticker_name + ".csv").dropna()
    data.index = pd.to_datetime(data["Date"])

    output = {}

    output["previous_close"] = "{:,.2f}".format(data.iloc[-1]["Close"])
    output["today_open"] = "{:,.2f}".format(data.iloc[-1]["Open"])
    output["today_volume"] = "{:,.2f}".format(data.iloc[-1]["Volume"])

    recent_data = data[-50:]
    recent_data['Volume'].mean()
    output["avg_volume"] = "{:,.0f}".format(recent_data["Volume"].mean())

    last_row = data.iloc[-1]
    today_range = (
        "{:,.2f}".format(last_row["Low"]) + " - " + "{:,.2f}".format(last_row["High"])
    )
    output["range_days"] = today_range

    last_year_data = data.last("52W")
    year_range = (
        "{:,.2f}".format(last_year_data["Low"].min())
        + " - "
        + "{:,.2f}".format(last_year_data["High"].max())
    )
    output["range_52"] = year_range

    output["MA_50"] = round(data["Close"].rolling(window=50).mean().iloc[-1], 1)
    output["MA_200"] = round(data["Close"].rolling(window=200).mean().iloc[-1], 1)

    return output

# %%
def group_output(ticker_name):
    data = pd.read_csv(ticker_name + ".csv").dropna()
    data.index = pd.to_datetime(data["Date"])

    output = {}

    output["previous_close"] = "{:,.2f}".format(data.iloc[-1]["Close"])
    output["today_open"] = "{:,.2f}".format(data.iloc[-1]["Open"])
    output["today_volume"] = "{:,.2f}".format(data.iloc[-1]["Volume"])
    
    recent_data = data[-50:]
    recent_data['Volume'].mean()
    output["avg_volume"] = "{:,.0f}".format(recent_data["Volume"].mean())

    last_row = data.iloc[-1]
    today_range = (
        "{:,.2f}".format(last_row["Low"]) + " - " + "{:,.2f}".format(last_row["High"])
    )
    output["range_days"] = today_range

    last_year_data = data.last("52W")
    year_range = (
        "{:,.2f}".format(last_year_data["Low"].min())
        + " - "
        + "{:,.2f}".format(last_year_data["High"].max())
    )
    output["range_52"] = year_range

    output["MA_50"] = round(data["Close"].rolling(window=50).mean().iloc[-1], 1)
    output["MA_200"] = round(data["Close"].rolling(window=200).mean().iloc[-1], 1)

    tick = yf.Ticker(ticker_name)

    output["Beta"] = tick.info["beta"]

    num = tick.info["enterpriseValue"]
    if num >= 10**12:  # 천억 이상
        output["enterprise"] = str(round(num / 10**12, 2)) + "T"
    elif num >= 10**8:  # 백만 이상
        output["enterprise"] = str(round(num / 10**8, 2)) + "M"
    else:
        output["enterprise"] = str(num)

    output["Buy"] = tick.info["bid"]
    output["Sell"] = tick.info["ask"]

    return output

# %%
country_output("^KS11")
# Out:
# C:\Users\cho03\AppData\Local\Temp\ipykernel_9148\3973377379.py:21: FutureWarning: last is deprecated and will be removed in a future version. Please create a mask and filter using `.loc` instead
#   last_year_data = data.last("52W")
# {'previous_close': '2,561.24',
#  'today_open': '2,598.31',
#  'today_volume': '791,214.00',
#  'avg_volume': '447,042',
#  'range_days': '2,556.00 - 2,599.37',
#  'range_52': '2,273.97 - 2,675.80',
#  'MA_50': 2501.6,
#  'MA_200': 2524.9}

# %%
country_output("^VNINDEX.VN")
# Out:
# C:\Users\cho03\AppData\Local\Temp\ipykernel_9148\3973377379.py:21: FutureWarning: last is deprecated and will be removed in a future version. Please create a mask and filter using `.loc` instead
#   last_year_data = data.last("52W")
# {'previous_close': '1,158.59',
#  'today_open': '1,160.19',
#  'today_volume': '870,510.00',
#  'avg_volume': '774,036',
#  'range_days': '1,155.46 - 1,162.83',
#  'range_52': '1,013.37 - 1,255.11',
#  'MA_50': 1130.7,
#  'MA_200': 1118.6}

# %%
group_output("055550.KS")
# Out:
# C:\Users\cho03\AppData\Local\Temp\ipykernel_9148\1930060354.py:21: FutureWarning: last is deprecated and will be removed in a future version. Please create a mask and filter using `.loc` instead
#   last_year_data = data.last("52W")
# {'previous_close': '37,250.00',
#  'today_open': '37,450.00',
#  'today_volume': '388,703.00',
#  'avg_volume': '791,931',
#  'range_days': '36,800.00 - 37,500.00',
#  'range_52': '32,400.00 - 44,900.00',
#  'MA_50': 36813.0,
#  'MA_200': 35523.2,
#  'Beta': 0.621,
#  'enterprise': '65.57T',
#  'Buy': 37300.0,
#  'Sell': 37350.0}

# %%
group_output("VCB.VN")
# Out:
# C:\Users\cho03\AppData\Local\Temp\ipykernel_9148\1930060354.py:21: FutureWarning: last is deprecated and will be removed in a future version. Please create a mask and filter using `.loc` instead
#   last_year_data = data.last("52W")
# {'previous_close': '87,800.00',
#  'today_open': '86,800.00',
#  'today_volume': '2,074,500.00',
#  'avg_volume': '1,549,419',
#  'range_days': '86,800.00 - 87,900.00',
#  'range_52': '72,057.58 - 93,400.00',
#  'MA_50': 85244.0,
#  'MA_200': 84131.3,
#  'Beta': 0.769,
#  'enterprise': '166.96T',
#  'Buy': 87800.0,
#  'Sell': 87900.0}

# %%
def output_news():
    data = pd.read_excel('market.xlsx')
    data = data.set_index('Date')
    return data

# %%
output_news()
# Out:
#                                  Korean  \
# Date
# 2000-03-10  코스닥 지수 사상 최고치 기록(2,834.40P)
# 2001-08-23                  IMF 관리체제 탈피
# 2001-09-11                    미국 911 테러
# 2002-10-14                    ETF 시장 개설
# 2003-03-20                    미국.이라크 전쟁
# ...                                 ...
# 2023-09-23                항저우 아시안 게임 개최
# 2023-10-07                 하마스, 이스라엘 전쟁
# 2023-11-05                 주식 공매도 금지 실시
# 2023-11-17              국가 행정망 전산 마비 사태
# 2023-11-23           북한, 9.19 남북군사합의 파기
#
#                                                       English  \
# Date
# 2000-03-10            Record high of KOSDAQ index (2,834.40P)
# 2001-08-23                  Escape from IMF management system
# 2001-09-11                                      US 911 Terror
# 2002-10-14                          Opening of the ETF market
# 2003-03-20                                        US-Iraq War
# ...                                                       ...
# 2023-09-23                          Hangzhou Asian Games held
# 2023-10-07                             Hamas, war with Israel
# 2023-11-05      Implementation of short selling ban on stocks
# 2023-11-17   National administrative network computer failure
# 2023-11-23  North Korea, scrapping the 9.19 South-North Mi...
#
#                                                    Vietnamese
# Date
# 2000-03-10    Chỉ số KOSDAQ ghi nhận mức cao nhất (2,834.40P)
# 2001-08-23                Thoát khỏi hệ thống quản lý của IMF
# 2001-09-11                                Khủng bố 911 tại Mỹ
# 2002-10-14                                  Mở thị trường ETF
# 2003-03-20                                Chiến tranh Mỹ-Iraq
# ...                                                       ...
# 2023-09-23      Tổ chức Đại hội thể thao châu Á tại Hàng Châu
# 2023-10-07                      Hamas, chiến tranh với Israel
# 2023-11-05                    Thực thi cấm bán cổ phiếu khống
# 2023-11-17  Sự cố hỏng hệ thống máy tính mạng quản lý quốc...
# 2023-11-23     Bắc Hàn, hủy bỏ Hiệp định Quân sự Nam-Bắc 9.19
#
# [105 rows x 3 columns]

# %%
def output_learn():
    data = pd.read_excel("learn.xlsx")
    data = data.set_index('Indicators')
    return data

output_learn()
# Out:
#                                                                           Korea  \
# Indicators
# Bollinger Bands                             주가가 상대적으로 높은지 낮은지를 주가의 변동성을 측정하는 기법
# Price Channel                 특정 기간 동안의 최고가와 최저가를 연결한 선으로, 주가의 상승세와 하락세를 판단하...
# Linear Fit                                             주가의 추세를 선형 방정식으로 표현하는 방법
# Quadratic Fit                                          주가의 추세를 2차 방정식으로 표현하는 방법
# Cubic Fit                                              주가의 추세를 3차 방정식으로 표현하는 방법
# Quartic Fit                                            주가의 추세를 4차 방정식으로 표현하는 방법
# Quintic Fit                                            주가의 추세를 5차 방정식으로 표현하는 방법
# Logarithmic Fit                                          주가의 추세를 로그 함수로 표현하는 방법
# Exponential Fit                                          주가의 추세를 지수 함수로 표현하는 방법
# PowerLaw Fit                                           주가의 추세를 거듭제곱 함수로 표현하는 방법
# Simple Average                일정 기간 동안의 주가를 단순히 모두 더한 후 그 기간으로 나눈 값입니다. 이를 통...
# Exponential Average           최근의 주가에 더 큰 가중치를 주어 계산하는 평균입니다. 최근의 주가 변동이 과거의...
# Modified Average              특정 계산 방법에 따른 평균값을 말합니다. 예를 들어, 특정 이벤트가 발생했을 때 ...
# Cumulative Average            일정 기간 동안의 주가를 모두 더한 후, 그 기간으로 나눠 계산하는 평균입니다. 단...
# Weighted Average              주가의 변동에 가중치를 부여하여 평균을 계산하는 방법입니다. 가중치는 일반적으로 시...
# Absolute Volume Oscillator        두 개의 이동 평균(일반적으로 7일과 14일) 사이의 거래량 차이를 측정하는 지표
# Accumulation Distribution     가격과 거래량의 변동을 결합하여 주식이 얼마나 적극적으로 매수 또는 매도되고 있는지...
# Standalone Indicators            특정 기간 동안의 최고가와 최저가를 기반으로 주식의 현재 가격 위치를 측정하는 지표
# Average True Range            가격 변동성을 측정하는 지표로, 일정 기간 동안의 최고가와 최저가, 그리고 전일 종...
# Bollinger Band Width          볼린저 밴드의 상단선과 하단선 사이의 거리를 측정하는 지표입니다. 이 값이 클수록 ...
# Chaikin Oscillator                               적 분산 지표의 이동 평균 사이의 차이를 측정하는 지표
# Chaikin Volatility                            고가와 저가의 차이를 이용하여 주가의 변동성을 측정하는 지표
# Commodity Channel Index              주가가 일정 기간 동안의 평균 가격에 비해 얼마나 변동했는지를 측정하는 지표
# Detrended Price Oscillator              주가의 장기 추세를 제거하여 중기 또는 단기 가격 변동을 확인하는 지표
# Ease Of Movement                 가격 변동과 거래량을 결합하여 주가가 얼마나 쉽게 움직일 수 있는지를 측정하는 지표
# Fast Stochastic Oscillator           주가가 일정 기간 동안의 가격 범위 내에서 어디에 위치하는지를 측정하는 지표
# Force Index                              가격, 거래량, 그리고 시간을 결합하여 주가의 변동성을 측정하는 지표
# Full Stochastic Oscillator    Fast Stochastic Oscillator를 추가로 평활화하여 더 부드러운 결...
# Market Facilitation Index                     가격 변동과 거래량을 결합하여 시장의 움직임을 측정하는 지표
# Mass Index                                      가격 범위(고가와 저가의 차이)의 변동성을 측정하는 지표
# Median Price                                  특정 기간 동안의 최고가와 최저가의 중간 값을 나타내는 지표
# Money Flow Index                     가격과 거래량을 결합하여 주식이 과매수 또는 과매도 상태인지를 측정하는 지표
# MACD                                                    두 개의 이동 평균의 차이를 측정하는 지표
# Negative Volume Index                               거래량이 감소하는 날의 주가 변동을 추적하는 지표
# On Balance Volume             가격과 거래량의 변동을 결합하여 주식이 얼마나 강력하게 매수 또는 매도되고 있는지 ...
# Percentage Price Oscillator                         두 개의 이동 평균의 퍼센트 차이를 측정하는 지표
# Percentage Volume Oscillator                    두 개의 이동 평균의 볼륨 차이를 퍼센트로 표현하는 지표
# Positive Volume Index                               거래량이 증가하는 날의 주가 변동을 추적하는 지표
# Price Volume Trend                            거래량과 가격 변동을 결합하여 주식의 수익률을 추적하는 지표
# ROC                                                   특정 기간 동안의 가격 변동률을 측정하는 지표
# RSI                           최근의 가격 상승일과 하락일의 평균 변동을 비교하여 주가의 상대적인 강도를 측정하는 지표
# Standard Deviation                                             주가의 변동성을 측정하는 지표
# Stoch RSI                        RSI의 값에 기반한 스토캐스틱 지표로, 주가의 상대적인 강도를 더욱 민감하게 반영
# TRIX                                                 가격의 세 번의 이동 평균을 기반으로 하는 지표
# Typical Price                                       하루 동안의 최고가, 최저가, 종가의 평균을 계산
# Ultimate Oscillator              단기, 중기, 장기의 세 가지 시간 프레임을 결합하여 주식의 모멘텀을 측정하는 지표
# Weighted Closez                   일일 최고가, 최저가, 그리고 종가의 두 배를 합한 후 4로 나누어 계산하는 지표
# Williams %R                    주식의 현재 가격이 최근 거래일 동안의 가격 범위에서 어디에 위치하는지를 측정하는 지표
#
#                                                                         English  \
# Indicators
# Bollinger Bands               Technique of measuring whether the stock price...
# Price Channel                 Line connecting the highest and lowest prices ...
# Linear Fit                    Method of representing the trend of stock pric...
# Quadratic Fit                 Method of representing the trend of stock pric...
# Cubic Fit                     Method of representing the trend of stock pric...
# Quartic Fit                   Method of representing the trend of stock pric...
# Quintic Fit                   Method of representing the trend of stock pric...
# Logarithmic Fit               Method of representing the trend of stock pric...
# Exponential Fit               Method of representing the trend of stock pric...
# PowerLaw Fit                  Method of representing the trend of stock pric...
# Simple Average                The value obtained by simply adding all the st...
# Exponential Average           The average calculated by giving more weight t...
# Modified Average              It refers to the average value according to a ...
# Cumulative Average            The average is calculated by adding all the st...
# Weighted Average              It is a method of calculating the average by g...
# Absolute Volume Oscillator    Indicator measuring the difference in trading ...
# Accumulation Distribution     Indicator measuring how actively a stock is be...
# Standalone Indicators         Indicator measuring the current price position...
# Average True Range            Indicator measuring price volatility, which is...
# Bollinger Band Width          Indicator measuring the distance between the u...
# Chaikin Oscillator            Indicator measuring the difference between the...
# Chaikin Volatility            Indicator measuring stock price volatility usi...
# Commodity Channel Index       Indicator measuring how much the stock price h...
# Detrended Price Oscillator    Indicator to check medium or short-term price ...
# Ease Of Movement              Indicator measuring how easily a stock price c...
# Fast Stochastic Oscillator    Indicator measuring where the stock price is l...
# Force Index                   Indicator measuring stock price volatility by ...
# Full Stochastic Oscillator    Indicator providing smoother results by furthe...
# Market Facilitation Index     Indicator measuring market movement by combini...
# Mass Index                    Indicator measuring the volatility of the pric...
# Median Price                  Indicator representing the median value of the...
# Money Flow Index              Indicator measuring whether a stock is overbou...
# MACD                          Indicator measuring the difference between two...
# Negative Volume Index         Indicator tracking stock price fluctuations on...
# On Balance Volume             Indicator measuring how strongly a stock is be...
# Percentage Price Oscillator   Indicator measuring the percentage difference ...
# Percentage Volume Oscillator  Indicator expressing the volume difference bet...
# Positive Volume Index         Indicator tracking stock price fluctuations on...
# Price Volume Trend            Indicator tracking the ROI of a stock by combi...
# ROC                           Indicator measuring the rate of price change o...
# RSI                           Indicator measuring the relative strength of t...
# Standard Deviation            Indicator measuring the volatility of a stock ...
# Stoch RSI                     Stochastic indicator based on the RSI value, m...
# TRIX                          Indicator based on the three moving averages o...
# Typical Price                 Calculate the average of the highest, lowest, ...
# Ultimate Oscillator           Indicator measuring the momentum of a stock by...
# Weighted Closez               Indicator calculated by adding the daily highe...
# Williams %R                   Indicator measuring where the current price of...
#
#                                                                         Vietnam
# Indicators
# Bollinger Bands               Kỹ thuật đo biến động giá cổ phiếu để xác định...
# Price Channel                 Sử dụng đường nối giữa giá cao nhất và thấp nh...
# Linear Fit                    Phương pháp biểu diễn xu hướng giá cổ phiếu bằ...
# Quadratic Fit                 Phương pháp biểu diễn xu hướng giá cổ phiếu bằ...
# Cubic Fit                     Phương pháp biểu diễn xu hướng giá cổ phiếu bằ...
# Quartic Fit                   Phương pháp biểu diễn xu hướng giá cổ phiếu bằ...
# Quintic Fit                   Phương pháp biểu diễn xu hướng giá cổ phiếu bằ...
# Logarithmic Fit               Phương pháp biểu diễn xu hướng giá cổ phiếu bằ...
# Exponential Fit               Phương pháp biểu diễn xu hướng giá cổ phiếu bằ...
# PowerLaw Fit                  Phương pháp biểu diễn xu hướng giá cổ phiếu bằ...
# Simple Average                Giá trị được chia cho thời gian sau khi đơn gi...
# Exponential Average           Trung bình được tính toán bằng cách đưa ra trọ...
# Modified Average              Trung bình dựa trên phương pháp tính toán cụ t...
# Cumulative Average            Trung bình được tính bằng cách chia tổng giá c...
# Weighted Average              Phương pháp tính trung bình bằng cách gán trọn...
# Absolute Volume Oscillator    Chỉ số đo sự khác biệt trong khối lượng giao d...
# Accumulation Distribution     Chỉ số đo mức độ mua hoặc bán chứng khoán mạnh...
# Standalone Indicators         Chỉ số đo vị trí giá hiện tại của cổ phiếu dựa...
# Average True Range            Chỉ số đo biến động giá bằng cách lấy trung bì...
# Bollinger Band Width          Chỉ số đo khoảng cách giữa dải trên và dải dướ...
# Chaikin Oscillator            Chỉ số đo sự khác biệt giữa trung bình di động...
# Chaikin Volatility            Chỉ số sử dụng sự khác biệt giữa giá cao và gi...
# Commodity Channel Index       Chỉ số đo mức độ biến động của giá cổ phiếu so...
# Detrended Price Oscillator    Chỉ số loại bỏ xu hướng dài hạn của giá cổ phi...
# Ease Of Movement              Chỉ số kết hợp biến động giá và khối lượng gia...
# Fast Stochastic Oscillator    Chỉ số đo vị trí của giá cổ phiếu trong phạm v...
# Force Index                   Chỉ số kết hợp giá, khối lượng giao dịch, và t...
# Full Stochastic Oscillator    Chỉ số làm mịn thêm Fast Stochastic Oscillator...
# Market Facilitation Index     Chỉ số đo lường sự di chuyển của thị trường bằ...
# Mass Index                    Chỉ số đo lường biến động của phạm vi giá (sự ...
# Median Price                  Chỉ số biểu thị giá trị trung bình giữa giá ca...
# Money Flow Index              Chỉ số đo lường xem cổ phiếu đang ở trạng thái...
# MACD                          Chỉ số đo lường sự khác biệt giữa hai trung bì...
# Negative Volume Index         Chỉ số theo dõi biến động giá cổ phiếu vào nhữ...
# On Balance Volume             Chỉ số đo lường mức độ mạnh mẽ mà cổ phiếu đan...
# Percentage Price Oscillator   Chỉ số đo lường sự khác biệt phần trăm giữa ha...
# Percentage Volume Oscillator  Chỉ số biểu thị sự khác biệt về khối lượng giữ...
# Positive Volume Index         Chỉ số theo dõi biến động giá cổ phiếu vào nhữ...
# Price Volume Trend            Chỉ số theo dõi lợi nhuận của cổ phiếu bằng cá...
# ROC                           Chỉ số đo lường tỷ lệ biến động giá trong một ...
# RSI                           Chỉ số đo lường sức mạnh tương đối của giá cổ ...
# Standard Deviation                   Chỉ số đo lường biến động của giá cổ phiếu
# Stoch RSI                     Chỉ số Stochastic dựa trên giá trị RSI, phản á...
# TRIX                              Chỉ số dựa trên ba trung bình di động của giá
# Typical Price                 Tính trung bình giá cao nhất, thấp nhất, và gi...
# Ultimate Oscillator           Chỉ số đo lường động lực của cổ phiếu bằng các...
# Weighted Closez               Chỉ số được tính bằng cách cộng giá cao nhất h...
# Williams %R                   Chỉ số đo lường vị trí hiện tại của giá cổ phi...
